# %%
import llm_agent_helpers as q

# %%
q.ask_question("What import statements should I include to make calls to the OpenAI API?")
# Out:
# To make calls to the OpenAI API using the Python SDK, include the following import statement:
#
# ```python
# from openai import OpenAI
# ```
#
# Then, you can create a client instance like this:
#
# ```python
# client = OpenAI()
# ```
#
# This setup lets you call the OpenAI API endpoints through the `client` object.

# %%
q.ask_question("Building on that, where would I put my API key?")
# Out:
# You should set your OpenAI API key in the environment variable `OPENAI_API_KEY` before running your Python code. For example, in your terminal or shell:
#
# ```bash
# export OPENAI_API_KEY="your_api_key_here"
# ```
#
# Then, when you create the client in Python:
#
# ```python
# from openai import OpenAI
#
# client = OpenAI()  # The client automatically reads the key from the environment
# ```
#
# Alternatively, if you want to set the key directly in code (less secure), you can do:
#
# ```python
# import os
# from openai import OpenAI
#
# os.environ["OPENAI_API_KEY"] = "your_api_key_here"
# client = OpenAI()
# ```
#
# But using environment variables is recommended for security.

# %%
q.reset_memory()
# Out:
# Conversation history reset.

# %%
q.ask_question("For the alternative you gave me, what would come next?")
# Out:
# Could you please clarify which alternative you are referring to? Once I have that context, I can help outline the next steps.
